# %% [markdown]
# ### Business case: To predict the flight price for the airlines which helps their costumers.

# %% [markdown]
# ### About the dataset
#
# - The data set is related to Airlines and their     flights.
# - It contains the journey details of the           passengers. such as name of airlines, route,     price.

# %% [markdown]
# ### Importing basic libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing the dataset

# %%
data = pd.read_csv('Flight_Fare.csv')
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %% [markdown]
# ### Domain Analysis

# %% [raw]
# 1. Airline:           It shows the name of the Airlines.
#
# 2. Date_of_Journey:   The date on which the passenger’s journey will start.
#
# 3. Source:            The name of the place from where the passenger’s journey will start.
#
# 4. Destination:       The name of the place to where passengers wanted to travel.
#
# 5. Route:             The route in which passengers have opted to travel from source to their                               destination.
#
# 6. Dep_time:          Depature time is when the passenger will leave from his/her source.
#
# 7. Arrival_Time:      Arrival time is when the passenger will reach his/her destination.
#
# 8. Duration:          Duration is the whole period that a flight will take to complete its journey                           from source to destination.
#
# 9. Total_Stops:       This will let us know in how many places flights will stop there for the flight                       in the whole journey.
#
# 10. Additional_Info:  In this column, we will get information about food, kind of food, and other                           amenities.
#
# 11. Price:            Price of the flight for a complete journey including all the expenses before                           onboarding.

# %% [markdown]
# ### BASIC CHECKS

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
data.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ### Univariate analysis

# %%
plt.figure(figsize=(20,15))
sns.countplot(data=data,x= 'Airline')
# Out:
# <Axes: xlabel='Airline', ylabel='count'>

# %% [markdown]
# ### Insights
#
# - **Jet Airways** is the most preferred airlines by the passengers compared to others.
# - **Indigo** and **Air india** are the second most preferred airlines by passengers.

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=data, x='Source')
# Out:
# <Axes: xlabel='Source', ylabel='count'>

# %% [markdown]
# ### INSIGHTS
#
# - More than 4000 passengers choose **Delhi** as their source compared to others.
# - Very less passengers choose **Chennai** as source.

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=data, x='Destination')
# Out:
# <Axes: xlabel='Destination', ylabel='count'>

# %% [markdown]
# ### Insights
# -  More than 4000 passenger has **Cochin** as their destination.
#    Also, frequency for Cochin is highest compared to other Destination.
#
# -  Very less passenger has **Kolkata** as their destination.

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data, x='Total_Stops')
# Out:
# <Axes: xlabel='Total_Stops', ylabel='count'>

# %% [markdown]
# ### Insights
#
# -  **1 Stop** has highest frequency than all the other stops. So ,we can say that most passenger are      preferring **1 stop**.
# -  We can clearly see that **3 and 4 stops** has very less frequency. So ,we can say that as the stops    is increasing number of passenger is decreasing.

# %%
plt.figure(figsize=(20,15))
sns.countplot(data=data, x='Additional_Info')
# Out:
# <Axes: xlabel='Additional_Info', ylabel='count'>

# %% [markdown]
# ### Insights
#
# - **No info** has more count compared to other and **In flight meal not included**
#   is the second highest info by passengers.

# %%
sns.histplot(data=data,x='Price', bins=50)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# ### Insights
# - Average Price for a flight is aorund **9,000**   rupees
# - Very few passenger are paying more than         **20,000** rupees

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
plt.figure(figsize=(20,15))
sns.boxplot(data=data, x= 'Airline', y = 'Price')
plt.show()

# %% [markdown]
# ### Insights
# -  **Jet Airways Business** is costliest compared to all the other airlines.
# -  Highest price for a airlins is also **Jet Airways Business** having Price of around 80,000.
# -  Most of the Airline has Price between 5,000 to 15,000 rupees.

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=data, x= 'Source', y = 'Price',kind="boxen")
plt.show()

# %% [markdown]
# ### Insights
#
# - People who are taking flight from **Banglore** are paying more than other source's.
# - **Chennai** has very less price compared to other.

# %%
plt.figure(figsize=(10,5))
sns.catplot(data=data, x= 'Destination', y = 'Price',kind="boxen")
plt.show()

# %% [markdown]
# ### Insights
# - Passenger's are paying more for travelling to **Delhi** as compared to other Destination.

# %% [markdown]
# ### DATA PREPROCESSING

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 220

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# ### ENCODING

# %% [markdown]
# ### Numerical features

# %% [markdown]
# ### Date_of_Journey

# %%
data["Date_of_Journey"] = pd.to_datetime(data["Date_of_Journey"])

# %%
data["Journey_Day"] = data["Date_of_Journey"].dt.day

# %%
data["Journey_Month"]= data["Date_of_Journey"].dt.month

# %%
data["Journey_DOW"] = data["Date_of_Journey"].dt.dayofweek

# %%
data.drop("Date_of_Journey",axis=1,inplace=True)

# %% [markdown]
# ### Dep_Time

# %%
data["Dep_Hour"] = pd.to_datetime(data["Dep_Time"]).dt.hour

# %%
data["Dep_Minute"] = pd.to_datetime(data["Dep_Time"]).dt.minute

# %%
data.drop("Dep_Time",axis=1,inplace=True)

# %% [markdown]
# ### Arrival_Time

# %%
data["Arrival_Hour"] = pd.to_datetime(data["Arrival_Time"]).dt.hour

# %%
data["Arrival_Minute"] = pd.to_datetime(data["Arrival_Time"]).dt.minute

# %%
data.drop("Arrival_Time",axis=1,inplace=True)

# %% [markdown]
# ### Duration

# %%
data['Duration'] = data['Duration'].str.replace('h','*60').str.replace(' ','+').str.replace('m','*1').apply(eval)

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# ### Airline

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data["Airline"].value_counts()
# Out:
# Jet Airways                          3700
# IndiGo                               2043
# Air India                            1694
# Multiple carriers                    1196
# SpiceJet                              815
# Vistara                               478
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
data["Airline"] = le.fit_transform(data["Airline"])

# %% [markdown]
# ### Source

# %%
data["Source"].value_counts()
# Out:
# Delhi       4345
# Kolkata     2860
# Banglore    2179
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
data['Source'] = le.fit_transform(data['Source'])

# %% [markdown]
# ### Destination

# %%
data["Destination"].value_counts()
# Out:
# Cochin       4345
# Banglore     2860
# Delhi        1265
# New Delhi     914
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
data['Destination'] = le.fit_transform(data['Destination'])

# %%
data.drop(columns='Route',axis=1,inplace=True)

# %% [markdown]
# ### Total_Stops

# %%
data.Total_Stops.value_counts()
# Out:
# 1 stop      5625
# non-stop    3475
# 2 stops     1318
# 3 stops       43
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
data["Total_Stops"] = data["Total_Stops"].replace({"non-stop" : 0,
                                                         "1 stop" : 1,
                                                         "2 stops" : 2,
                                                         "3 stops" : 3,
                                                         "4 stops" : 4})

# %% [markdown]
# ### Additional_Info

# %%
data.Additional_Info.value_counts()
# Out:
# No info                         8182
# In-flight meal not included     1926
# No check-in baggage included     318
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
data.Additional_Info=data.Additional_Info.map({'No info':8,'No Info':8,'In-flight meal not included':7,'No check-in baggage included':6,'1 Long layover':5,'Change airports':4,'Business class':3,'1 Short layover':2,'Red-eye flight':1,'2 Long layover':0})

# %%
data
# Out:
#        Airline  Source  Destination  Duration  Total_Stops  Additional_Info  \
# 0            3       0            5       170            0                8
# 1            1       3            0       445            2                8
# 2            4       2            1      1140            2                8
# 3            3       3            0       325            1                8
# 4            3       0            5       285            1                8
# ...        ...     ...          ...       ...          ...              ...
# 10678        0       3            0       150            0                8
# 10679        1       3            0       155            0                8
# 10680        4       0            2       180            0                8
# 10681       10       0            5       160            0                8
# 10682        1       2            1       500            2                8
#
# ...

# %% [markdown]
# ### Checking outliers

# %%
df = data[['Price']]

# %%
plt.figure(figsize=(10,5),facecolor='white')

plotnumber=1

for column in df:
    if plotnumber<=2 :
        ax=plt.subplot(1,2,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column)
       
    plotnumber+=1
plt.tight_layout()

# %%
from scipy import stats

# %%
Q1 = df.quantile(0.25)  # np.percentile(data,25)

Q3 = df.quantile(0.75)

IQR = Q3-Q1

min_limit = Q1 - 1.5*IQR

max_limit = Q3 + 1.5*IQR

outliers_count = ((df > max_limit) | (df < min_limit)).sum()

outliers_percentage = (outliers_count/len(df))*100

print('\n Sum of Outliers:\n ',outliers_count)
print('\n Percentage of Outliers:\n ',outliers_percentage)
# Out:
#  Sum of Outliers:
#   Price    94
# dtype: int64
#
#  Percentage of Outliers:
#   Price    0.89849
# dtype: float64

# %% [markdown]
# ### Handling Outliers

# %%
Q1 = np.percentile(data.Price,25)
Q3 = np.percentile(data.Price,75)

IQR = stats.iqr(data['Price'])

max_limit = Q3+(1.5*IQR)
min_limit = Q1-(1.5*IQR)

data.loc[(data['Price'] > max_limit) | (data['Price'] < min_limit),'Price'] = np.median(data['Price'])

# %%
data
# Out:
#        Airline  Source  Destination  Duration  Total_Stops  Additional_Info  \
# 0            3       0            5       170            0                8
# 1            1       3            0       445            2                8
# 2            4       2            1      1140            2                8
# 3            3       3            0       325            1                8
# 4            3       0            5       285            1                8
# ...        ...     ...          ...       ...          ...              ...
# 10678        0       3            0       150            0                8
# 10679        1       3            0       155            0                8
# 10680        4       0            2       180            0                8
# 10681       10       0            5       160            0                8
# 10682        1       2            1       500            2                8
#
# ...

# %% [markdown]
# ### FEATURE SELECTION

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(),annot=True,cmap="inferno")
# Out:
# <Axes: >

# %%
data.corr()["Price"]
# Out:
# Airline           -0.041462
# Source             0.074518
# Destination       -0.165823
# Duration           0.564858
# Total_Stops        0.662478
# Additional_Info    0.080561
# Price              1.000000
# Journey_Day       -0.147984
# Journey_Month      0.068811
# Journey_DOW       -0.004968
# Dep_Hour           0.004967
# Dep_Minute        -0.053522
# Arrival_Hour       0.045999
# Arrival_Minute    -0.097136
# Name: Price, dtype: float64

# %% [markdown]
# ### SPLITTING THE DATA

# %%
# x,y split
x = data.drop("Price",axis=1)
y = data["Price"]

# %%
# Train, Test split
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (7846, 13)
# (7846,)
# (2616, 13)
# (2616,)

# %% [markdown]
# ### MODEL IMPLEMENTATION

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "ElasticNet Regression": ElasticNet(),
    "SVR": SVR(kernel='rbf'),
    "Decision Tree Regression": DecisionTreeRegressor(),
    "Random Forest Regression": RandomForestRegressor(),
    "Gradient Boosting Regression": GradientBoostingRegressor(),
    "XGBoost Regression": XGBRegressor()
}

Model_name = []
Model_acc = []

# Train and evaluate models
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test) 
    print(name)
    print(f"MAE: {mean_absolute_error(y_test, y_pred):.4f}")
    print(f"MSE: {mean_squared_error(y_test, y_pred):.4f}")
    print(f"RMSE: {np.sqrt(mean_squared_error(y_test, y_pred)):.4f}")
    print(f"R^2 Score: {r2_score(y_test,y_pred):.4f}")
    print("-"*50)
    Model_name.append(name)
    Model_acc.append(f"{r2_score(y_test,y_pred):.4f}")
# Out:
# Linear Regression
# MAE: 2246.5022
# MSE: 8120993.7349
# RMSE: 2849.7357
# R^2 Score: 0.5065
# --------------------------------------------------
# Ridge Regression
# MAE: 2246.5098
# MSE: 8121074.6501
# RMSE: 2849.7499
# R^2 Score: 0.5065
# --------------------------------------------------
# Lasso Regression
# MAE: 2246.4624
# MSE: 8121418.9444
# RMSE: 2849.8103
# R^2 Score: 0.5065
# --------------------------------------------------
# ElasticNet Regression
# MAE: 2443.4992
# MSE: 9478172.9815
# RMSE: 3078.6642
# R^2 Score: 0.4240
# --------------------------------------------------
# SVR
# MAE: 2910.1875
# MSE: 13197431.5524
# RMSE: 3632.8269
# R^2 Score: 0.1980
# --------------------------------------------------
# Decision Tree Regression
# MAE: 765.3259
# MSE: 2846209.1362
# RMSE: 1687.0712
# R^2 Score: 0.8270
# --------------------------------------------------
# Random Forest Regression
# MAE: 654.5816
# MSE: 1595048.2557
# RMSE: 1262.9522
# R^2 Score: 0.9031
# ...

# %% [markdown]
# ### Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Define parameter grids for each model
param_grids = {
    "Linear Regression": {},
    "Ridge Regression": {"alpha": [0.1, 1.0, 10.0, 100.0]},
    "Lasso Regression": {"alpha": [0.1, 1.0, 10.0, 100.0]},
    "ElasticNet Regression": {"alpha": [0.1, 1.0, 10.0, 100.0], "l1_ratio": [0.2, 0.5, 0.8]},
    "SVR": {"C": [0.1, 1, 10, 100], "gamma": [0.001, 0.01, 0.1, 1]},
    "Decision Tree Regression": {"max_depth": [None, 10, 20, 30], "min_samples_split": [2, 10, 20]},
    "Random Forest Regression": {"n_estimators": [100, 200, 500], "max_depth": [None, 10, 20, 30], "min_samples_split": [2, 10, 20]},
    "Gradient Boosting Regression": {"n_estimators": [100, 200, 500], "learning_rate": [0.01, 0.1, 0.2], "max_depth": [3, 5, 7]},
    "XGBoost Regression": {"n_estimators": [100, 200, 500], "learning_rate": [0.01, 0.1, 0.2], "max_depth": [3, 5, 7]}
}

Hyper_model=[]
Hyper_model_acc=[]

# Hyperparameter tuning and model evaluation
for name, model in models.items():
    print(f"Training {name}...")
    if param_grids[name]:
        grid_search = GridSearchCV(model, param_grids[name], cv=5, scoring='r2', n_jobs=-1, verbose=1)
        grid_search.fit(x_train, y_train)
        best_model = grid_search.best_estimator_
    else:
        model.fit(x_train, y_train)
        best_model = model
    
    y_pred = best_model.predict(x_test)
    print(name)
    print(f"MAE: {mean_absolute_error(y_test, y_pred):.4f}")
    print(f"MSE: {mean_squared_error(y_test, y_pred):.4f}")
    print(f"RMSE: {np.sqrt(mean_squared_error(y_test, y_pred)):.4f}")
    print(f"R^2 Score: {r2_score(y_test,y_pred):.4f}")
    print("-"*50)
    Hyper_model.append(name)
    Hyper_model_acc.append(f"{r2_score(y_test,y_pred):.4f}")
# Out:
# Training Linear Regression...
# Linear Regression
# MAE: 2246.5022
# MSE: 8120993.7349
# RMSE: 2849.7357
# R^2 Score: 0.5065
# --------------------------------------------------
# Training Ridge Regression...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Ridge Regression
# MAE: 2246.5098
# MSE: 8121074.6501
# RMSE: 2849.7499
# R^2 Score: 0.5065
# --------------------------------------------------
# Training Lasso Regression...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Lasso Regression
# MAE: 2246.4624
# MSE: 8121418.9444
# RMSE: 2849.8103
# R^2 Score: 0.5065
# --------------------------------------------------
# Training ElasticNet Regression...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# ElasticNet Regression
# MAE: 2252.1613
# MSE: 8153468.5411
# RMSE: 2855.4279
# R^2 Score: 0.5045
# --------------------------------------------------
# Training SVR...
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# SVR
# ...

# %% [markdown]
# ### MODEL COMPARISON REPORT

# %%
table = pd.DataFrame({"Model Name" : Model_name,"R2 Score" : Model_acc})

# %%
table.sort_values(by="R2 Score",ascending=False,ignore_index=True)
# Out:
#                      Model Name R2 Score
# 0      Random Forest Regression   0.9031
# 1            XGBoost Regression   0.9003
# 2      Decision Tree Regression   0.8270
# 3  Gradient Boosting Regression   0.8131
# 4             Linear Regression   0.5065
# 5              Ridge Regression   0.5065
# 6              Lasso Regression   0.5065
# 7         ElasticNet Regression   0.4240
# 8                           SVR   0.1980

# %%
#After hyperparameter tuning
table2 = pd.DataFrame({"Model Name" : Hyper_model,"R2 Score" :Hyper_model_acc })
table2.sort_values(by="R2 Score",ascending=False,ignore_index=True)
# Out:
#                      Model Name R2 Score
# 0            XGBoost Regression   0.9079
# 1  Gradient Boosting Regression   0.9065
# 2      Random Forest Regression   0.9041
# 3      Decision Tree Regression   0.8525
# 4                           SVR   0.5111
# 5             Linear Regression   0.5065
# 6              Ridge Regression   0.5065
# 7              Lasso Regression   0.5065
# 8         ElasticNet Regression   0.5045

# %% [markdown]
# - By applying the regression models, its clear that **XGBRegressor** is highly predictive model compared to all others

# %% [markdown]
# ### CONCLUSION
#
# - A complete data analysis is done on the given     data
# - **XGBRegressor** is highly predictive model compared to all others, which can be used by the Airlines for flight price prediction and maintain it for customer needs.
